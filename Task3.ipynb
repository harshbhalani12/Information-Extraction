# %%
import spacy
from nltk.corpus import wordnet
nlp = spacy.load('en')

# %%
paragraph = "It was selected by the American Film Institute as one of the ten best films of the year. Filming at Edwards Air Force Base began in mid-April, and ended on May 2."
lexical_dict = lexical_segmantation(paragraph)

# %%
lexical_dict
# Out:
# {'Filming at Edwards Air Force Base began in mid-April, and ended on May 2.': {'POS_tag': {Filming: 'VBG',
#    at: 'IN',
#    Edwards: 'NNP',
#    Air: 'NNP',
#    Force: 'NNP',
#    Base: 'NNP',
#    began: 'VBD',
#    in: 'IN',
#    mid: 'JJ',
#    -: 'HYPH',
#    April: 'NNP',
#    ,: ',',
#    and: 'CC',
#    ended: 'VBD',
#    on: 'IN',
#    May: 'NNP',
#    2: 'CD',
#    .: '.'},
#   'dependency_tree': [['Filming', 'nsubj', 'began', 'VERB', [at]],
#    ['at', 'prep', 'Filming', 'VERB', [Base]],
#    ['Edwards', 'compound', 'Base', 'PROPN', []],
#    ['Air', 'compound', 'Force', 'PROPN', []],
#    ['Force', 'compound', 'Base', 'PROPN', [Air]],
#    ['Base', 'pobj', 'at', 'ADP', [Edwards, Force]],
#    ['began', 'ROOT', 'began', 'VERB', [Filming, in, ,, and, ended, .]],
#    ['in', 'prep', 'began', 'VERB', []],
#    ['mid', 'amod', 'April', 'PROPN', []],
#    ['-', 'punct', 'April', 'PROPN', []],
#    ['April', 'punct', ',', 'PUNCT', [mid, -]],
#    [',', 'punct', 'began', 'VERB', [April]],
#    ['and', 'cc', 'began', 'VERB', []],
#    ['ended', 'conj', 'began', 'VERB', [on]],
#    ['on', 'prep', 'ended', 'VERB', [May]],
#    ['May', 'pobj', 'on', 'ADP', [2]],
#    ['2', 'nummod', 'May', 'PROPN', []],
#    ['.', 'punct', 'began', 'VERB', []]],
#   'lemmas': ['film',
#    'at',
#    'edwards',
#    'air',
#    'force',
#    'base',
#    'begin',
#    'in',
#    'mid',
#    '-',
#    'april',
#    ',',
#    'and',
#    'end',
#    'on',
#    'may',
#    '2',
#    '.'],
#   'word_net_info': {',': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    '-': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    '.': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    '2': {'holonyms': [],
#     'hypernyms': ['digit', 'figure'],
#     'hyponyms': ['couple',
#      'pair',
#      'twosome',
#      'twain',
#      'brace',
#      'span',
#      'yoke',
#      'couplet',
#      'distich',
#      'duo',
#      'duet',
#      'dyad',
#      'duad',
#      'craps',
#      'snake_eyes'],
#     'meronyms': [],
#     'synonyms': ['deuce', '2', 'II', 'two', 'ii']},
#    'air': {'holonyms': [],
#     'hypernyms': ['gas',
#      'region',
#      'part',
#      'quality',
#      'wind',
#      'air_current',
#      'current_of_air',
#      'region',
#      'part',
#      'element',
#      'music',
#      'medium',
#      'travel',
#      'traveling',
#      'travelling',
#      'expose',
#      'publicize',
#      'publicise',
#      'air',
#      'bare',
#      'tell',
#      'dry',
#      'dry_out',
#      'refresh',
#      'freshen'],
#     'hyponyms': ['breath',
#      'hot_air',
#      'liquid_air',
#      'mystique',
#      'note',
#      'vibration',
#      'vibe',
#      'breath',
#      'fresh_breeze',
#      'gentle_breeze',
#      'light_air',
#      'light_breeze',
#      'moderate_breeze',
#      'sea_breeze',
#      'strong_breeze',
#      'airspace',
#      'flourish',
#      'fanfare',
#      'tucket',
#      'glissando',
#      'leitmotiv',
#      'leitmotif',
#      'part',
#      'voice',
#      'roulade',
#      'signature',
#      'signature_tune',
#      'theme_song',
#      'theme',
#      'melodic_theme',
#      'musical_theme',
#      'idea',
#      'theme_song',
#      'flight',
#      'flying',
#      'get_on',
#      'be_on',
#      'interrogate',
#      'rerun',
#      'rebroadcast',
#      'satellite',
#      'sportscast',
#      'telecast',
#      'televise',
#      'air',
#      'send',
#      'broadcast',
#      'beam',
#      'transmit',
#      'bulletin',
#      'circulate',
#      'circularize',
#      'circularise',
#      'distribute',
#      'disseminate',
#      'propagate',
#      'broadcast',
#      'spread',
#      'diffuse',
#      'disperse',
#      'pass_around',
#      'hype',
#      'publish',
#      'bring_out',
#      'put_out',
#      'issue',
#      'release'],
#     'meronyms': ['airspace',
#      'air_space',
#      'ionosphere',
#      'phrase',
#      'musical_phrase'],
#     'synonyms': ['send',
#      'airwave',
#      'aura',
#      'melodic_phrase',
#      'breeze',
#      'atmosphere',
#      'beam',
#      'tune',
#      'air_travel',
#      'melodic_line',
#      'gentle_wind',
#      'aerate',
#      'air_out',
#      'broadcast',
#      'bare',
#      'air',
#      'melody',
#      'aviation',
#      'strain',
#      'publicize',
#      'transmit',
#      'ventilate',
#      'vent',
#      'zephyr',
#      'publicise',
#      'line']},
#    'and': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    'april': {'holonyms': [],
#     'hypernyms': ['Gregorian_calendar_month'],
#     'hyponyms': [],
#     'meronyms': ["April_Fools'",
#      "April_Fools'_day",
#      "All_Fools'_day",
#      'mid-April',
#      'Pan_American_Day',
#      'April_14',
#      "Patriot's_Day"],
#     'synonyms': ['April', 'Apr']},
#    'at': {'holonyms': [],
#     'hypernyms': ['chemical_element',
#      'element',
#      'halogen',
#      'Laotian_monetary_unit'],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': ['atomic_number_85', 'astatine', 'At', 'at']},
#    'base': {'holonyms': [],
#     'hypernyms': ['military_installation',
#      'support',
#      'baseball_equipment',
#      'part',
#      'piece',
#      'bottom',
#      'control',
#      'assumption',
#      'supposition',
#      'supposal',
#      'support',
#      'ester',
#      'compound',
#      'chemical_compound',
#      'flank',
#      'part',
#      'portion',
#      'component_part',
#      'component',
#      'constituent',
#      'number',
#      'location',
#      'form',
#      'word_form',
#      'signifier',
#      'descriptor',
#      'store',
#      'stock',
#      'fund',
#      'ingredient',
#      'bottom',
#      'underside',
#      'undersurface',
#      'electrode',
#      'situate',
#      'locate',
#      'drug',
#      'do_drugs'],
#     'hyponyms': ['air_base',
#      'air_station',
#      'army_base',
#      'firebase',
#      'navy_base',
#      'rocket_base',
#      'bed',
#      'raft_foundation',
#      'first_base',
#      'home_plate',
#      'home_base',
#      'home',
#      'plate',
#      'second_base',
#      'third_base',
#      'third',
#      'price_floor',
#      'wage_floor',
#      'meat_and_potatoes',
#      'brass_monkey',
#      'staddle',
#      'trivet',
#      'trivet',
#      'adenosine_diphosphate',
#      'ADP',
#      'adenosine_monophosphate',
#      'AMP',
#      'adenylic_acid',
#      'adenosine_triphosphate',
#      'ATP',
#      'base_pair',
#      'deoxyadenosine_monophosphate',
#      'A',
#      'deoxycytidine_monophosphate',
#      'C',
#      'deoxyguanosine_monophosphate',
#      'G',
#      'deoxythymidine_monophosphate',
#      'T',
#      'muton',
#      'uracil',
#      'U',
#      'imidazole',
#      'iminazole',
#      'glyoxaline',
#      'melamine',
#      'cyanuramide',
#      'purine',
#      'purine',
#      'pyridine',
#      'pyrimidine',
#      'build'],
#     'meronyms': ['communication_system',
#      'communication_equipment',
#      'fire_station',
#      'firehouse',
#      'gas_system',
#      'main',
#      'penal_institution',
#      'penal_facility',
#      'power_system',
#      'power_grid',
#      'grid',
#      'public_works',
#      'school_system',
#      'sewage_system',
#      'sewer_system',
#      'sewage_works',
#      'transportation_system',
#      'transportation',
#      'transit',
#      'water_system',
#      'water_supply',
#      'water'],
#     'synonyms': ['radix',
#      'immoral',
#      'theme',
#      'radical',
#      'meanspirited',
#      'Qaeda',
#      'root_word',
#      'ground',
#      'baseborn',
#      'foundation',
#      'base',
#      'understructure',
#      'substructure',
#      'bag',
#      'home',
#      'found',
#      'infrastructure',
#      'al-Qaeda',
#      'pedestal',
#      'Base',
#      'al-Qaida',
#      'humble',
#      'free-base',
#      'foot',
#      'cornerstone',
#      "al-Qa'ida",
#      'establish',
#      'basal',
#      'groundwork',
#      'root',
#      'basis',
#      'stand',
#      'mean',
#      'nucleotide',
#      'fundament',
#      'lowly',
#      'base_of_operations',
#      'alkali',
#      'floor',
#      'stem']},
#    'begin': {'holonyms': [],
#     'hypernyms': ['talk',
#      'speak',
#      'utter',
#      'mouth',
#      'verbalize',
#      'verbalise',
#      'be',
#      'be',
#      'act',
#      'move',
#      'achieve',
#      'accomplish',
#      'attain',
#      'reach'],
#     'hyponyms': ['attack',
#      'auspicate',
#      'break_in',
#      'come_on',
#      'embark',
#      'enter',
#      'fall',
#      'get_cracking',
#      'bestir_oneself',
#      'get_going',
#      'get_moving',
#      'get_weaving',
#      'get_started',
#      'get_rolling',
#      'get_to',
#      'jump_off',
#      'plunge',
#      'launch',
#      'recommence',
#      'strike_out',
#      'break_out',
#      'bud',
#      'dawn',
#      'erupt',
#      'break_out',
#      'originate',
#      'set_in',
#      'kick_in',
#      'inaugurate',
#      'usher_in',
#      'introduce',
#      'jumpstart',
#      'jump-start',
#      'recommence',
#      'set_off',
#      'start',
#      'start_up',
#      'embark_on',
#      'commence'],
#     'meronyms': [],
#     'synonyms': ['commence',
#      'Begin',
#      'get_down',
#      'begin',
#      'set_about',
#      'set_out',
#      'get',
#      'Menachem_Begin',
#      'start_out',
#      'start',
#      'lead_off']},
#    'edwards': {'holonyms': ['Windsor',
#      'House_of_Windsor',
#      'Saxe-Coburg-Gotha'],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': ['Duke_of_Windsor',
#      'Black_Prince',
#      'Edward_I',
#      'Edward_II',
#      'Edward_VII',
#      'Edward_IV',
#      'Jonathan_Edwards',
#      'Edwards',
#      'Albert_Edward',
#      'Prince_Edward',
#      'Edward_VI',
#      'Edward_Antony_Richard_Louis',
#      'Edward_V',
#      'Edward_VIII',
#      'Edward',
#      'Edward_III']},
#    'end': {'holonyms': ['football_team', 'eleven'],
#     'hypernyms': ['extremity',
#      'point',
#      'point_in_time',
#      'ending',
#      'conclusion',
#      'finish',
#      'content',
#      'cognitive_content',
#      'mental_object',
#      'part',
#      'section',
#      'division',
#      'state',
#      'surface',
#      'lineman',
#      'boundary',
#      'bound',
#      'bounds',
#      'topographic_point',
#      'place',
#      'spot',
#      'contribution',
#      'part',
#      'share',
#      'section',
#      'subdivision',
#      'piece_of_cloth',
#      'piece_of_material',
#      'lineman',
#      'change',
#      'alter',
#      'modify',
#      'be',
#      'destroy',
#      'destruct'],
#     'hyponyms': ['bitter_end',
#      'bitthead',
#      'end_point',
#      'endpoint',
#      'termination',
#      'terminus',
#      'finish',
#      'destination',
#      'goal',
#      'heel',
#      'heel',
#      'nerve_ending',
#      'nerve_end',
#      'point',
#      'pole',
#      'magnetic_pole',
#      'railhead',
#      'telomere',
#      'terminus',
#      'tip',
#      'yardarm',
#      'cease',
#      'death',
#      'dying',
#      'demise',
#      'death',
#      'last',
#      'fag_end',
#      'tail',
#      'tail_end',
#      'last_gasp',
#      'period',
#      'stopping_point',
#      'finale',
#      'finis',
#      'finish',
#      'last',
#      'conclusion',
#      'close',
#      'termination',
#      'expiration',
#      'expiry',
#      'terminus_ad_quem',
#      'terminal_point',
#      'limit',
#      'year-end',
#      'endgame',
#      'end_game',
#      'endgame',
#      'end_game',
#      'homestretch',
#      'passing',
#      'aim',
#      'object',
#      'objective',
#      'target',
#      'bourn',
#      'bourne',
#      'destination',
#      'terminus',
#      'end-all',
#      'intention',
#      'no-goal',
#      'purpose',
#      'intent',
#      'intention',
#      'aim',
#      'design',
#      'split_end',
#      'tight_end',
#      'anticlimax',
#      'bathos',
#      'epilogue',
#      'epilog',
#      'epilogue',
#      'epilog',
#      'finale',
#      'coda',
#      'peroration',
#      'fag_end',
#      'adjourn',
#      'recess',
#      'break_up',
#      'break',
#      'conclude',
#      'close',
#      'culminate',
#      'climax',
#      'cut_out',
#      'discontinue',
#      'go_out',
#      'lapse',
#      'pass_away',
#      'run_low',
#      'run_short',
#      'go',
#      'run_out',
#      'turn_out',
#      'come_out',
#      'vanish',
#      'disappear',
#      'go_away',
#      'vanish',
#      'disappear',
#      'abort',
#      'ax',
#      'axe',
#      'break',
#      'break_off',
#      'discontinue',
#      'stop',
#      'close',
#      'close',
#      'close_out',
#      'closure',
#      'cloture',
#      'complete',
#      'finish',
#      'conclude',
#      'culminate',
#      'decide',
#      'settle',
#      'resolve',
#      'adjudicate',
#      'dissolve',
#      'break_up',
#      'dissolve',
#      'break_up',
#      'finalize',
#      'finalise',
#      'settle',
#      'nail_down',
#      'finish',
#      'interrupt',
#      'break',
#      'lift',
#      'raise',
#      'phase_out',
#      'stamp_out',
#      'kill',
#      'stub_out',
#      'crush_out',
#      'extinguish',
#      'press_out',
#      'close'],
#     'meronyms': [],
#     'synonyms': ['final_stage',
#      'ending',
#      'cease',
#      'terminate',
#      'death',
#      'end',
#      'closing',
#      'remnant',
#      'finish',
#      'close',
#      'stop',
#      'remainder',
#      'goal',
#      'conclusion',
#      'oddment',
#      'last',
#      'destruction',
#      'terminal']},
#    'film': {'holonyms': [],
#     'hypernyms': ['product',
#      'production',
#      'show',
#      'medium',
#      'photographic_paper',
#      'photographic_material',
#      'object',
#      'physical_object',
#      'sheet',
#      'flat_solid',
#      'wrapping',
#      'wrap',
#      'wrapper',
#      'record',
#      'enter',
#      'put_down',
#      'make',
#      'create',
#      'record',
#      'enter',
#      'put_down'],
#     'hyponyms': ['cinema_verite',
#      'collage_film',
#      'coming_attraction',
#      'documentary',
#      'docudrama',
#      'documentary_film',
#      'infotainment',
#      'feature',
#      'feature_film',
#      'film_noir',
#      'final_cut',
#      'home_movie',
#      'musical',
#      'musical_comedy',
#      'musical_theater',
#      'rough_cut',
#      "shoot-'em-up",
#      'short_subject',
#      'silent_movie',
#      'silent_picture',
#      'silents',
#      'skin_flick',
#      'slow_motion',
#      'talking_picture',
#      'talkie',
#      'telefilm',
#      'three-D',
#      '3-D',
#      '3D',
#      'silver_screen',
#      'film_clip',
#      'footage',
#      'microfilm',
#      'motion-picture_film',
#      'movie_film',
#      'cine-film',
#      'negative',
#      'orthochromatic_film',
#      'panchromatic_film',
#      'positive',
#      'reel',
#      'roll',
#      'roll_film',
#      'sequence',
#      'episode',
#      'X-ray_film',
#      'scum',
#      'slick',
#      'soap_film',
#      'Polaroid',
#      'shrink-wrap',
#      'reshoot',
#      'cinematize',
#      'cinematise',
#      'microfilm'],
#     'meronyms': ['credit',
#      'credits',
#      'scene',
#      'shot',
#      'sequence',
#      'episode',
#      'subtitle',
#      'caption'],
#     'synonyms': ['moving-picture_show',
#      'film',
#      'take',
#      'motion-picture_show',
#      'pic',
#      'motion_picture',
#      'cinema',
#      'shoot',
#      'plastic_film',
#      'picture',
#      'flick',
#      'movie',
#      'moving_picture',
#      'celluloid',
#      'picture_show',
#      'photographic_film']},
#    'force': {'holonyms': ['military_service', 'armed_service', 'service'],
#     'hypernyms': ['influence',
#      'physical_phenomenon',
#      'intensity',
#      'intensiveness',
#      'organization',
#      'organisation',
#      'unit',
#      'social_unit',
#      'aggression',
#      'hostility',
#      'causal_agent',
#      'cause',
#      'causal_agency',
#      'social_group',
#      'validity',
#      'validness',
#      'putout',
#      'compel',
#      'oblige',
#      'obligate',
#      'cause',
#      'do',
#      'make',
#      'move',
#      'displace',
#      'compel',
#      'oblige',
#      'obligate',
#      'move',
#      'displace',
#      'thrust',
#      'move',
#      'displace',
#      'act',
#      'move',
#      'penetrate',
#      'perforate'],
#     'hyponyms': ['duress',
#      'heartbeat',
#      'lifeblood',
#      'pressure',
#      'wheel',
#      'aerodynamic_force',
#      'affinity',
#      'chemical_attraction',
#      'attraction',
#      'attractive_force',
#      'centrifugal_force',
#      'centripetal_force',
#      'cohesion',
#      'Coriolis_force',
#      'drift',
#      'impetus',
#      'impulsion',
#      'life_force',
#      'vital_force',
#      'vitality',
#      'elan_vital',
#      'Lorentz_force',
#      'magnetomotive_force',
#      'moment',
#      'propulsion',
#      'pull',
#      'push',
#      'thrust',
#      'reaction',
#      'repulsion',
#      'repulsive_force',
#      'stress',
#      'torsion',
#      'torque',
#      'brunt',
#      'energy',
#      'vigor',
#      'vigour',
#      'zip',
#      'momentum',
#      'impulse',
#      'guerrilla_force',
#      'guerilla_force',
#      'line_personnel',
#      'management_personnel',
#      'military',
#      'armed_forces',
#      'armed_services',
#      'military_machine',
#      'war_machine',
#      'military_personnel',
#      'soldiery',
#      'troops',
#      'military_police',
#      'MP',
#      'military_service',
#      'armed_service',
#      'service',
#      'paramilitary',
#      'paramilitary_force',
#      'paramilitary_unit',
#      'paramilitary_organization',
#      'paramilitary_organisation',
#      'patrol',
#      'police',
#      'police_force',
#      'constabulary',
#      'law',
#      'rank_and_file',
#      'rank',
#      'security_force',
#      'private_security_force',
#      'staff',
#      'work_force',
#      'workforce',
#      'manpower',
#      'hands',
#      'men',
#      'air_unit',
#      'armor',
#      'armour',
#      'army_unit',
#      'command',
#      'commando',
#      'contingent',
#      'detail',
#      'echelon',
#      'enemy',
#      'guard',
#      'Haganah',
#      'headquarters',
#      'Israeli_Defense_Force',
#      'IDF',
#      'legion',
#      'militia',
#      'reserves',
#      'mujahidin',
#      'mujahedin',
#      'mujahedeen',
#      'mujahadeen',
#      'mujahadin',
#      'mujahideen',
#      'mujahadein',
#      'naval_unit',
#      'phalanx',
#      'Republican_Guard',
#      'spearhead',
#      'task_force',
#      'trip_wire',
#      'domestic_violence',
#      'riot',
#      'public_violence',
#      'road_rage',
#      'influence',
#      'juggernaut',
#      'steamroller',
#      'Moloch',
#      'bludgeon',
#      'bring_oneself',
#      'dragoon',
#      'sandbag',
#      'railroad',
#      'drive',
#      'squeeze_for',
#      'steamroller',
#      'steamroll',
#      'terrorize',
#      'terrorise',
#      'turn_up_the_heat',
#      'turn_up_the_pressure',
#      'drive',
#      'jam',
#      'jerk',
#      'flick',
#      'jostle',
#      'shove',
#      'muscle_into',
#      'nose',
#      'nudge',
#      'poke_at',
#      'prod',
#      'press',
#      'push',
#      'push_aside',
#      'push_away',
#      'push_out',
#      'obtrude',
#      'thrust_out',
#      'push_up',
#      'repel',
#      'drive',
#      'repulse',
#      'force_back',
#      'push_back',
#      'beat_back',
#      'shove',
#      'thrust',
#      'thrust',
#      'stuff',
#      'shove',
#      'squeeze',
#      'topple',
#      'tumble',
#      'tip',
#      'stick',
#      'sting',
#      'compress',
#      'compact',
#      'pack_together',
#      'impact',
#      'toe',
#      'toenail',
#      'abduct',
#      'adduct',
#      'attract',
#      'pull',
#      'pull_in',
#      'draw',
#      'draw_in',
#      'drag',
#      'haul',
#      'hale',
#      'cart',
#      'drag',
#      'pluck',
#      'tweak',
#      'pull_off',
#      'pick_off',
#      'pluck',
#      'plunk',
#      'pick',
#      'pull_back',
#      'stretch',
#      'tug',
#      'twitch',
#      'winch',
#      'yank',
#      'jerk',
#      'pull'],
#     'meronyms': [],
#     'synonyms': ['force-out',
#      'thrust',
#      'strength',
#      'force_out',
#      'storm',
#      'impel',
#      'power',
#      'hale',
#      'force_play',
#      'military_force',
#      'effect',
#      'violence',
#      'coerce',
#      'force',
#      'pressure',
#      'ram',
#      'squeeze',
#      'pull',
#      'wedge',
#      'forcefulness',
#      'military_group',
#      'push',
#      'military_unit',
#      'draw',
#      'personnel',
#      'drive']},
#    'in': {'holonyms': [],
#     'hypernyms': ['linear_unit',
#      'linear_measure',
#      'metallic_element',
#      'metal'],
#     'hyponyms': [],
#     'meronyms': ['em',
#      'pica_em',
#      'pica',
#      'ligne',
#      'mesh',
#      'mil',
#      'Bloomington',
#      'Evansville',
#      'Fort_Wayne',
#      'Gary',
#      'Indianapolis',
#      'capital_of_Indiana',
#      'Lafayette',
#      'Muncie',
#      'South_Bend',
#      'Wabash',
#      'Wabash_River'],
#     'synonyms': ['Indiana',
#      'inwards',
#      'In',
#      'inch',
#      'in',
#      'IN',
#      'indium',
#      'inward',
#      'atomic_number_49',
#      'Hoosier_State']},
#    'may': {'holonyms': ['Crataegus', 'genus_Crataegus'],
#     'hypernyms': ['Gregorian_calendar_month', 'hawthorn', 'haw'],
#     'hyponyms': [],
#     'meronyms': ['Armed_Forces_Day',
#      'Commonwealth_Day',
#      'Empire_day',
#      'May_24',
#      'May_Day',
#      'First_of_May',
#      'May_1',
#      'Memorial_Day',
#      'Decoration_Day',
#      'mid-May',
#      "Mother's_Day"],
#     'synonyms': ['Crataegus_laevigata',
#      'Crataegus_oxycantha',
#      'may',
#      'English_hawthorn',
#      'May',
#      'whitethorn']},
#    'mid': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': ['mid']},
#    'on': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': ['along', 'on']}}},
#  'It was selected by the American Film Institute as one of the ten best films of the year.': {'POS_tag': {It: 'PRP',
#    was: 'VBD',
#    selected: 'VBN',
#    by: 'IN',
#    the: 'DT',
#    American: 'NNP',
#    Film: 'NNP',
#    Institute: 'NNP',
#    as: 'IN',
#    one: 'CD',
#    of: 'IN',
#    the: 'DT',
#    ten: 'CD',
#    best: 'JJS',
#    films: 'NNS',
#    of: 'IN',
#    the: 'DT',
#    year: 'NN',
#    .: '.'},
#   'dependency_tree': [['It', 'nsubjpass', 'selected', 'VERB', []],
#    ['was', 'auxpass', 'selected', 'VERB', []],
#    ['selected', 'ROOT', 'selected', 'VERB', [It, was, by, as, .]],
#    ['by', 'agent', 'selected', 'VERB', [Institute]],
#    ['the', 'det', 'Institute', 'PROPN', []],
#    ['American', 'compound', 'Institute', 'PROPN', []],
#    ['Film', 'compound', 'Institute', 'PROPN', []],
#    ['Institute', 'pobj', 'by', 'ADP', [the, American, Film]],
#    ['as', 'prep', 'selected', 'VERB', [one]],
#    ['one', 'pobj', 'as', 'ADP', [of]],
#    ['of', 'prep', 'one', 'NUM', [films]],
#    ['the', 'det', 'films', 'NOUN', []],
#    ['ten', 'nummod', 'films', 'NOUN', []],
#    ['best', 'amod', 'films', 'NOUN', []],
#    ['films', 'pobj', 'of', 'ADP', [the, ten, best, of]],
#    ['of', 'prep', 'films', 'NOUN', [year]],
#    ['the', 'det', 'year', 'NOUN', []],
#    ['year', 'pobj', 'of', 'ADP', [the]],
#    ['.', 'punct', 'selected', 'VERB', []]],
#   'lemmas': ['-PRON-',
#    'be',
#    'select',
#    'by',
#    'the',
#    'american',
#    'film',
#    'institute',
#    'as',
#    'one',
#    'of',
#    'the',
#    'ten',
#    'good',
#    'film',
#    'of',
#    'the',
#    'year',
#    '.'],
#   'word_net_info': {'-PRON-': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    '.': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    'american': {'holonyms': ['United_States',
#      'United_States_of_America',
#      'America',
#      'the_States',
#      'US',
#      'U.S.',
#      'USA',
#      'U.S.A.',
#      'Central_America',
#      'North_America',
#      'South_America'],
#     'hypernyms': ['inhabitant',
#      'habitant',
#      'dweller',
#      'denizen',
#      'indweller',
#      'English',
#      'English_language',
#      'inhabitant',
#      'habitant',
#      'dweller',
#      'denizen',
#      'indweller'],
#     'hyponyms': ['African-American',
#      'African_American',
#      'Afro-American',
#      'Black_American',
#      'Alabaman',
#      'Alabamian',
#      'Alaskan',
#      'Anglo-American',
#      'Appalachian',
#      'Arizonan',
#      'Arizonian',
#      'Arkansan',
#      'Arkansawyer',
#      'Asian_American',
#      'Bay_Stater',
#      'Bostonian',
#      'Californian',
#      'Carolinian',
#      'Coloradan',
#      'Connecticuter',
#      'Creole',
#      'Delawarean',
#      'Delawarian',
#      'Floridian',
#      'Franco-American',
#      'Georgian',
#      'German_American',
#      'Hawaiian',
#      'Idahoan',
#      'Illinoisan',
#      'Indianan',
#      'Hoosier',
#      'Iowan',
#      'Kansan',
#      'Kentuckian',
#      'Bluegrass_Stater',
#      'Louisianan',
#      'Louisianian',
#      'Mainer',
#      'Down_Easter',
#      'Marylander',
#      'Michigander',
#      'Wolverine',
#      'Minnesotan',
#      'Gopher',
#      'Mississippian',
#      'Missourian',
#      'Montanan',
#      'Nebraskan',
#      'Cornhusker',
#      'Nevadan',
#      'New_Englander',
#      'Yankee',
#      'New_Hampshirite',
#      'Granite_Stater',
#      'New_Jerseyan',
#      'New_Jerseyite',
#      'Garden_Stater',
#      'New_Mexican',
#      'New_Yorker',
#      'Nisei',
#      'North_Carolinian',
#      'Tarheel',
#      'North_Dakotan',
#      'Ohioan',
#      'Buckeye',
#      'Oklahoman',
#      'Sooner',
#      'Oregonian',
#      'Beaver',
#      'Pennsylvanian',
#      'Keystone_Stater',
#      'Puerto_Rican',
#      'Rhode_Islander',
#      'South_Carolinian',
#      'South_Dakotan',
#      'Southerner',
#      'Spanish_American',
#      'Hispanic_American',
#      'Hispanic',
#      'Tennessean',
#      'Volunteer',
#      'Texan',
#      'Tory',
#      'Utahan',
#      'Vermonter',
#      'Virginian',
#      'Washingtonian',
#      'Washingtonian',
#      'West_Virginian',
#      'Wisconsinite',
#      'Badger',
#      'Wyomingite',
#      'Yankee',
#      'Yank',
#      'Northerner',
#      'Yankee',
#      'Yank',
#      'Yankee-Doodle',
#      'African_American_Vernacular_English',
#      'AAVE',
#      'African_American_English',
#      'Black_English',
#      'Black_English_Vernacular',
#      'Black_Vernacular',
#      'Black_Vernacular_English',
#      'Ebonics',
#      'Creole',
#      'Latin_American',
#      'Latino',
#      'Mesoamerican',
#      'North_American',
#      'South_American',
#      'West_Indian'],
#     'meronyms': [],
#     'synonyms': ['American_English', 'American_language', 'American']},
#    'as': {'holonyms': ['Roman_alphabet', 'Latin_alphabet'],
#     'hypernyms': ['chemical_element',
#      'element',
#      'metric_linear_unit',
#      'fat-soluble_vitamin',
#      'nucleotide',
#      'base',
#      'purine',
#      'current_unit',
#      'letter',
#      'letter_of_the_alphabet',
#      'alphabetic_character',
#      'blood_group',
#      'blood_type'],
#     'hyponyms': ['vitamin_A1', 'retinol', 'vitamin_A2', 'dehydroretinol'],
#     'meronyms': ['Pago_Pago',
#      'Pango_Pango',
#      'picometer',
#      'picometre',
#      'micromicron',
#      'milliampere',
#      'mA'],
#     'synonyms': ['adenine',
#      'equally',
#      'A',
#      'angstrom',
#      'atomic_number_33',
#      'vitamin_A',
#      'ampere',
#      'angstrom_unit',
#      'as',
#      'group_A',
#      'American_Samoa',
#      'amp',
#      'As',
#      'Eastern_Samoa',
#      'axerophthol',
#      'arsenic',
#      'type_A',
#      'AS',
#      'deoxyadenosine_monophosphate',
#      'antiophthalmic_factor',
#      'every_bit',
#      'a']},
#    'be': {'holonyms': [],
#     'hypernyms': ['metallic_element',
#      'metal',
#      'typify',
#      'symbolize',
#      'symbolise',
#      'stand_for',
#      'represent',
#      'take',
#      'occupy',
#      'use_up',
#      'stay',
#      'remain',
#      'rest',
#      'be'],
#     'hyponyms': ['abound',
#      'accept',
#      'take',
#      'account',
#      'account_for',
#      'act',
#      'answer',
#      'appear',
#      'seem',
#      'bake',
#      'broil',
#      'balance',
#      'be_well',
#      'beat',
#      'begin',
#      'begin',
#      'start',
#      'belong',
#      'belong',
#      'belong',
#      'belong',
#      'breathe',
#      'buy',
#      'clean',
#      'cohere',
#      'come_in_for',
#      'come_in_handy',
#      'compact',
#      'pack',
#      'compare',
#      'confuse',
#      'throw',
#      'fox',
#      'befuddle',
#      'fuddle',
#      'bedevil',
#      'confound',
#      'discombobulate',
#      'connect',
#      'consist',
#      'consist',
#      'comprise',
#      'contain',
#      'contain',
#      'take',
#      'hold',
#      'continue',
#      'cost',
#      'be',
#      'count',
#      'matter',
#      'weigh',
#      'count',
#      'cover',
#      'cut',
#      'cut_across',
#      'deck',
#      'adorn',
#      'decorate',
#      'grace',
#      'embellish',
#      'beautify',
#      'depend',
#      'deserve',
#      'merit',
#      'disagree',
#      'disaccord',
#      'discord',
#      'distribute',
#      'diverge',
#      'draw',
#      'end',
#      'terminate',
#      'fall',
#      'come',
#      'fall',
#      'feel',
#      'figure',
#      'enter',
#      'fit',
#      'gape',
#      'yawn',
#      'yaw',
#      'go',
#      'gravitate',
#      'hail',
#      'come',
#      'hang',
#      'head',
#      'head_up',
#      'hold',
#      'hoodoo',
#      'hum',
#      'buzz',
#      'seethe',
#      'impend',
#      'incarnate',
#      'body_forth',
#      'embody',
#      'substantiate',
#      'iridesce',
#      'jumble',
#      'mingle',
#      'kill',
#      'lend',
#      'let_go',
#      'lie',
#      'litter',
#      'loiter',
#      'lounge',
#      'footle',
#      'lollygag',
#      'loaf',
#      'lallygag',
#      'hang_around',
#      'mess_about',
#      'tarry',
#      'linger',
#      'lurk',
#      'mill_about',
#      'mill_around',
#      'look',
#      'appear',
#      'seem',
#      'look',
#      'lubricate',
#      'make',
#      'make_sense',
#      'add_up',
#      'measure',
#      'mope',
#      'moon_around',
#      'moon_about',
#      'object',
#      'osculate',
#      'owe',
#      'pay',
#      'point',
#      'press',
#      'promise',
#      'prove',
#      'turn_out',
#      'turn_up',
#      'put_out',
#      'rage',
#      'range',
#      'run',
#      'rank',
#      'rate',
#      'recognize',
#      'relate',
#      'interrelate',
#      'remain',
#      'represent',
#      'rest',
#      'retard',
#      'run',
#      'go',
#      'run_into',
#      'encounter',
#      'rut',
#      'seem',
#      'seethe',
#      'boil',
#      'sell',
#      'sell',
#      'sell',
#      'shine',
#      'shine',
#      'sparkle',
#      'scintillate',
#      'coruscate',
#      'specify',
#      'define',
#      'delineate',
#      'delimit',
#      'delimitate',
#      'squat',
#      'stagnate',
#      'stagnate',
#      'stand',
#      'stand',
#      'stand_by',
#      'stick_by',
#      'stick',
#      'adhere',
#      'stay',
#      'remain',
#      'rest',
#      'stay',
#      'stay_on',
#      'continue',
#      'remain',
#      'stick',
#      'stink',
#      'subtend',
#      'delimit',
#      'suck',
#      'suffer',
#      'hurt',
#      'suffer',
#      'suit',
#      'swim',
#      'swim',
#      'drown',
#      'swing',
#      'tend',
#      'be_given',
#      'lean',
#      'incline',
#      'run',
#      'test',
#      'total',
#      'number',
#      'add_up',
#      'come',
#      'amount',
#      'translate',
#      'transplant',
#      'trim',
#      'underlie',
#      'want',
#      'need',
#      'require',
#      'wash',
#      'wind',
#      'twist',
#      'curve',
#      'work',
#      'attend',
#      'go_to',
#      'belong',
#      'go',
#      'center_on',
#      'come',
#      'cover',
#      'continue',
#      'extend',
#      'extend',
#      'poke_out',
#      'reach_out',
#      'face',
#      'follow',
#      'go',
#      'lead',
#      'inhabit',
#      'lie',
#      'lie',
#      'rest',
#      'occupy',
#      'fill',
#      'populate',
#      'dwell',
#      'live',
#      'inhabit',
#      'reach',
#      'extend_to',
#      'touch',
#      'run',
#      'go',
#      'pass',
#      'lead',
#      'extend',
#      'sit',
#      'sit_around',
#      'sit',
#      'stand_back',
#      "keep_one's_eyes_off",
#      "keep_one's_distance",
#      "keep_one's_hands_off",
#      'stay_away',
#      'straddle',
#      'stretch',
#      'stretch_along',
#      'coexist',
#      'come',
#      'distribute',
#      'dwell',
#      'consist',
#      'lie',
#      'lie_in',
#      'dwell',
#      'inhabit',
#      'endanger',
#      'jeopardize',
#      'jeopardise',
#      'menace',
#      'threaten',
#      'imperil',
#      'peril',
#      'flow',
#      'indwell',
#      'kick_around',
#      'knock_about',
#      'kick_about',
#      'preexist',
#      'prevail',
#      'hold',
#      'obtain',
#      'equate',
#      'correspond',
#      'match',
#      'fit',
#      'correspond',
#      'check',
#      'jibe',
#      'gibe',
#      'tally',
#      'agree',
#      'represent',
#      'stand_for',
#      'correspond',
#      'translate',
#      'compose',
#      'fall_into',
#      'fall_under',
#      'form',
#      'constitute',
#      'make',
#      'make',
#      'present',
#      'pose',
#      'range',
#      'straddle',
#      'supplement',
#      'cox',
#      'vet',
#      'body',
#      'personify',
#      'exemplify',
#      'represent',
#      'set_back',
#      'knock_back',
#      'put_back'],
#     'meronyms': [],
#     'synonyms': ['personify',
#      'equal',
#      'constitute',
#      'follow',
#      'cost',
#      'represent',
#      'live',
#      'Be',
#      'exist',
#      'embody',
#      'beryllium',
#      'be',
#      'comprise',
#      'atomic_number_4',
#      'glucinium',
#      'make_up']},
#    'by': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': ['by', 'aside', 'past', 'away']},
#    'film': {'holonyms': [],
#     'hypernyms': ['product',
#      'production',
#      'show',
#      'medium',
#      'photographic_paper',
#      'photographic_material',
#      'object',
#      'physical_object',
#      'sheet',
#      'flat_solid',
#      'wrapping',
#      'wrap',
#      'wrapper',
#      'record',
#      'enter',
#      'put_down',
#      'make',
#      'create',
#      'record',
#      'enter',
#      'put_down'],
#     'hyponyms': ['cinema_verite',
#      'collage_film',
#      'coming_attraction',
#      'documentary',
#      'docudrama',
#      'documentary_film',
#      'infotainment',
#      'feature',
#      'feature_film',
#      'film_noir',
#      'final_cut',
#      'home_movie',
#      'musical',
#      'musical_comedy',
#      'musical_theater',
#      'rough_cut',
#      "shoot-'em-up",
#      'short_subject',
#      'silent_movie',
#      'silent_picture',
#      'silents',
#      'skin_flick',
#      'slow_motion',
#      'talking_picture',
#      'talkie',
#      'telefilm',
#      'three-D',
#      '3-D',
#      '3D',
#      'silver_screen',
#      'film_clip',
#      'footage',
#      'microfilm',
#      'motion-picture_film',
#      'movie_film',
#      'cine-film',
#      'negative',
#      'orthochromatic_film',
#      'panchromatic_film',
#      'positive',
#      'reel',
#      'roll',
#      'roll_film',
#      'sequence',
#      'episode',
#      'X-ray_film',
#      'scum',
#      'slick',
#      'soap_film',
#      'Polaroid',
#      'shrink-wrap',
#      'reshoot',
#      'cinematize',
#      'cinematise',
#      'microfilm'],
#     'meronyms': ['credit',
#      'credits',
#      'scene',
#      'shot',
#      'sequence',
#      'episode',
#      'subtitle',
#      'caption'],
#     'synonyms': ['moving-picture_show',
#      'film',
#      'take',
#      'motion-picture_show',
#      'pic',
#      'motion_picture',
#      'cinema',
#      'shoot',
#      'plastic_film',
#      'picture',
#      'flick',
#      'movie',
#      'moving_picture',
#      'celluloid',
#      'picture_show',
#      'photographic_film']},
#    'good': {'holonyms': [],
#     'hypernyms': ['advantage',
#      'vantage',
#      'morality',
#      'quality',
#      'artifact',
#      'artefact'],
#     'hyponyms': ['common_good',
#      'commonweal',
#      'beneficence',
#      'benignity',
#      'benignancy',
#      'graciousness',
#      'kindness',
#      'saintliness',
#      'summum_bonum',
#      'virtue',
#      'virtuousness',
#      'moral_excellence',
#      'virtue',
#      'benefit',
#      'welfare',
#      'better',
#      'better',
#      'desirability',
#      'desirableness',
#      'optimum',
#      'wisdom',
#      'wiseness',
#      'soundness',
#      'worthiness',
#      'basic',
#      'staple',
#      'consumer_goods',
#      'drygoods',
#      'soft_goods',
#      'entrant',
#      'export',
#      'exportation',
#      'fancy_goods',
#      'fungible',
#      'future',
#      'import',
#      'importation',
#      'merchandise',
#      'ware',
#      'product',
#      'middling',
#      'salvage',
#      'shopping',
#      'sporting_goods',
#      'worldly_possession',
#      'worldly_good'],
#     'meronyms': [],
#     'synonyms': ['well',
#      'unspoiled',
#      'full',
#      'near',
#      'estimable',
#      'in_effect',
#      'skillful',
#      'serious',
#      'sound',
#      'trade_good',
#      'goodness',
#      'practiced',
#      'ripe',
#      'thoroughly',
#      'just',
#      'right',
#      'salutary',
#      'adept',
#      'dear',
#      'proficient',
#      'soundly',
#      'honest',
#      'beneficial',
#      'unspoilt',
#      'skilful',
#      'secure',
#      'safe',
#      'dependable',
#      'effective',
#      'good',
#      'upright',
#      'in_force',
#      'honorable',
#      'respectable',
#      'expert',
#      'undecomposed',
#      'commodity']},
#    'institute': {'holonyms': [],
#     'hypernyms': ['association', 'initiate', 'pioneer', 'make', 'create'],
#     'hyponyms': ['appoint', 'name', 'nominate', 'constitute', 'fix'],
#     'meronyms': [],
#     'synonyms': ['constitute',
#      'establish',
#      'bring',
#      'institute',
#      'found',
#      'plant']},
#    'of': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    'one': {'holonyms': [],
#     'hypernyms': ['digit', 'figure', 'unit'],
#     'hyponyms': ['monad', 'monas', 'singleton'],
#     'meronyms': [],
#     'synonyms': ['single',
#      'peerless',
#      'unrivalled',
#      'ane',
#      'unrivaled',
#      'i',
#      'nonpareil',
#      'ace',
#      'unitary',
#      'I',
#      'matchless',
#      'unmatched',
#      'unmatchable',
#      'one_and_only',
#      'unity',
#      'one',
#      '1']},
#    'select': {'holonyms': [],
#     'hypernyms': ['decide', "make_up_one's_mind", 'determine'],
#     'hyponyms': ['adopt',
#      'follow',
#      'espouse',
#      'anoint',
#      'assign',
#      'specify',
#      'set_apart',
#      'cream_off',
#      'skim_off',
#      'cull_out',
#      'winnow',
#      'dial',
#      'draw',
#      'elect',
#      'elect',
#      'empanel',
#      'impanel',
#      'panel',
#      'excerpt',
#      'extract',
#      'take_out',
#      'field',
#      'nominate',
#      'propose',
#      'pick',
#      'plump',
#      'go',
#      'screen',
#      'screen_out',
#      'sieve',
#      'sort',
#      'sieve',
#      'sift',
#      'sieve_out',
#      'pick_over',
#      'single_out',
#      'specify',
#      'set',
#      'determine',
#      'define',
#      'fix',
#      'limit',
#      'think_of',
#      'vote',
#      'vote_in'],
#     'meronyms': [],
#     'synonyms': ['prize',
#      'blue-ribbon',
#      'take',
#      'choose',
#      'quality',
#      'prime',
#      'select',
#      'choice',
#      'pick_out']},
#    'ten': {'holonyms': [],
#     'hypernyms': ['large_integer', 'spot'],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': ['tenner', 'X', 'ten-spot', '10', 'x', 'ten', 'decade']},
#    'the': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    'year': {'holonyms': [],
#     'hypernyms': ['time_period',
#      'period_of_time',
#      'period',
#      'time_period',
#      'period_of_time',
#      'period',
#      'time_period',
#      'period_of_time',
#      'period',
#      'gathering',
#      'assemblage'],
#     'hyponyms': ['annum',
#      'calendar_year',
#      'civil_year',
#      'church_year',
#      'Christian_year',
#      'common_year',
#      '365_days',
#      'fiscal_year',
#      'financial_year',
#      'Holy_Year',
#      'leap_year',
#      'intercalary_year',
#      '366_days',
#      'bissextile_year',
#      'New_Year',
#      'off_year',
#      'off_year',
#      'Y2K',
#      'year_of_grace',
#      'school_year',
#      'academic_year',
#      'anomalistic_year',
#      'lunar_year',
#      'sidereal_year',
#      'solar_year',
#      'tropical_year',
#      'astronomical_year',
#      'equinoctial_year',
#      'freshman_class',
#      'graduating_class',
#      'junior_class',
#      'senior_class',
#      'sophomore_class'],
#     'meronyms': ['month', 'season', 'time_of_year'],
#     'synonyms': ['twelvemonth', 'class', 'year', 'yr']}}}}

# %%
def get_sentence_tokens(paragraph):
    doc =  nlp(paragraph)
    return [sent.string.strip() for sent in doc.sents]

# %%
def get_word_tokens(sentence):
    doc =  nlp(sentence)
    return [token.text for token in doc]

# %%
def tokenize_POS_tag(sentence):
    doc = nlp(sentence)
    token_dict = {}
    
    for token in doc:
        token_dict[token]= token.tag_
    
    return token_dict

# %%
def get_lemmas(sentence):
    doc =  nlp(sentence)
    lemmas = []
    for token in doc:
        lemmas.append(token.lemma_)
    return lemmas

# %%
def get_dependency_tree_nodes(sentence):
    doc = nlp(sentence)
    nodes = []
    for token in doc:
        nodes.append([token.text, token.dep_, token.head.text, token.head.pos_,
          [child for child in token.children]])
    return nodes

# %%
def get_hypernym(token):
    hypernym_list = []
    
    synsets = wordnet.synsets(token)
    
    for synset in synsets:
        for hypernym in synset.hypernyms():
            for lemma in hypernym.lemmas():
                hypernym_list.append(lemma.name())
    
    return hypernym_list

# %%
def get_holonym(token):
    holonym_list = []
    
    synsets = wordnet.synsets(token)
    
    for synset in synsets:
        for holonym in synset.member_holonyms():
            for lemma in holonym.lemmas():
                holonym_list.append(lemma.name())
    
    return holonym_list

# %%
def get_hyponym(token):
    hyponym_list = []
    
    synsets = wordnet.synsets(token)
    
    for synset in synsets:
        for hyponym in synset.hyponyms():
            for lemma in hyponym.lemmas():
                hyponym_list.append(lemma.name())
    
    return hyponym_list

# %%
def get_meronym(token):
    meronym_list = []
    
    synsets = wordnet.synsets(token)
    
    for synset in synsets:
        for meronym in synset.part_meronyms():
            for lemma in meronym.lemmas():
                meronym_list.append(lemma.name())
    
    return meronym_list

# %%
def get_synonym(token):
    synonym_list = []
    
    synsets = wordnet.synsets(token)
    
    for synset in synsets:
        for lemma in synset.lemmas():
            synonym_list.append(lemma.name())
    
    return list(set(synonym_list))

# %%
print(get_synonym('release'))
# Out:
# ['press_release', 'outlet', 'exhaust', 'unloose', 'release', 'relinquish', 'handout', 'loose', 'button', 'tone_ending', 'put_out', 'sacking', 'spillage', 'spill', 'unfreeze', 'freeing', 'eject', 'liberation', 'unloosen', 'exit', 'loss', 'expiration', 'publish', 'waiver', 'unblock', 'issue', 'bring_out', 'dismissal', 'discharge', 'going', 'acquittance', 'departure', 'free', 'give_up', 'dismission', 'resign', 'secrete', 'firing', 'let_go_of', 'sack', 'vent', 'passing', 'let_go', 'expel', 'turn', 'liberate']

# %%
def get_word_net_data(token):
    data = {}
    
    hypernyms = get_hypernym(token)
    hyponyms = get_hyponym(token)
    meronyms = get_meronym(token)
    holonyms = get_holonym(token)
    synonyms = get_synonym(token)
    
    data['hypernyms'] = hypernyms
    data['hyponyms'] = hyponyms
    data['meronyms'] = meronyms
    data['holonyms'] = holonyms
    data['synonyms'] = synonyms
    
    return data

# %%
word_net_data = get_word_net_data('Jorge')
word_net_data
# Out:
# {'holonyms': [],
#  'hypernyms': [],
#  'hyponyms': [],
#  'meronyms': [],
#  'synonyms': []}

# %%
def sentence_data_dict(sentence):
    mega_dict = {}
    
    word_tokens = get_word_tokens(sentence)
    POS_tag = tokenize_POS_tag(sentence)
    lemmas = get_lemmas(sentence)
    
    word_net_info_dict = {} #{lemma1: {hyper:  , hypo:   , ....}, lemma2: {hyper:  , hypo:   , ....}}
    
    for lemma in lemmas:
        word_net_info_dict[lemma] = get_word_net_data(lemma)
        
    dependency_tree = get_dependency_tree_nodes(sentence)
    
    mega_dict['POS_tag'] = POS_tag
    mega_dict['lemmas'] = lemmas
    mega_dict['word_net_info'] = word_net_info_dict
    mega_dict['dependency_tree'] = dependency_tree
    
    return mega_dict

# %%
def lexical_segmantation(paragraph):
    lexical_dict = {}
    
    sentences = get_sentence_tokens(paragraph)
    for sentence in sentences:
        lexical_dict[sentence] = sentence_data_dict(sentence)
    
    return lexical_dict

# %%
paragraph = "It was selected by the American Film Institute as one of the ten best films of the year. Filming at Edwards Air Force Base began in mid-April, and ended on May 2."
lexical_dict = lexical_segmantation(paragraph)

# %%
lexical_dict
# Out:
# {'Filming at Edwards Air Force Base began in mid-April, and ended on May 2.': {'POS_tag': {Filming: 'VBG',
#    at: 'IN',
#    Edwards: 'NNP',
#    Air: 'NNP',
#    Force: 'NNP',
#    Base: 'NNP',
#    began: 'VBD',
#    in: 'IN',
#    mid: 'JJ',
#    -: 'HYPH',
#    April: 'NNP',
#    ,: ',',
#    and: 'CC',
#    ended: 'VBD',
#    on: 'IN',
#    May: 'NNP',
#    2: 'CD',
#    .: '.'},
#   'dependency_tree': [['Filming', 'nsubj', 'began', 'VERB', [at]],
#    ['at', 'prep', 'Filming', 'VERB', [Base]],
#    ['Edwards', 'compound', 'Base', 'PROPN', []],
#    ['Air', 'compound', 'Force', 'PROPN', []],
#    ['Force', 'compound', 'Base', 'PROPN', [Air]],
#    ['Base', 'pobj', 'at', 'ADP', [Edwards, Force]],
#    ['began', 'ROOT', 'began', 'VERB', [Filming, in, ,, and, ended, .]],
#    ['in', 'prep', 'began', 'VERB', []],
#    ['mid', 'amod', 'April', 'PROPN', []],
#    ['-', 'punct', 'April', 'PROPN', []],
#    ['April', 'punct', ',', 'PUNCT', [mid, -]],
#    [',', 'punct', 'began', 'VERB', [April]],
#    ['and', 'cc', 'began', 'VERB', []],
#    ['ended', 'conj', 'began', 'VERB', [on]],
#    ['on', 'prep', 'ended', 'VERB', [May]],
#    ['May', 'pobj', 'on', 'ADP', [2]],
#    ['2', 'nummod', 'May', 'PROPN', []],
#    ['.', 'punct', 'began', 'VERB', []]],
#   'lemmas': ['film',
#    'at',
#    'edwards',
#    'air',
#    'force',
#    'base',
#    'begin',
#    'in',
#    'mid',
#    '-',
#    'april',
#    ',',
#    'and',
#    'end',
#    'on',
#    'may',
#    '2',
#    '.'],
#   'word_net_info': {',': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    '-': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    '.': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    '2': {'holonyms': [],
#     'hypernyms': ['digit', 'figure'],
#     'hyponyms': ['couple',
#      'pair',
#      'twosome',
#      'twain',
#      'brace',
#      'span',
#      'yoke',
#      'couplet',
#      'distich',
#      'duo',
#      'duet',
#      'dyad',
#      'duad',
#      'craps',
#      'snake_eyes'],
#     'meronyms': [],
#     'synonyms': ['deuce', '2', 'II', 'two', 'ii']},
#    'air': {'holonyms': [],
#     'hypernyms': ['gas',
#      'region',
#      'part',
#      'quality',
#      'wind',
#      'air_current',
#      'current_of_air',
#      'region',
#      'part',
#      'element',
#      'music',
#      'medium',
#      'travel',
#      'traveling',
#      'travelling',
#      'expose',
#      'publicize',
#      'publicise',
#      'air',
#      'bare',
#      'tell',
#      'dry',
#      'dry_out',
#      'refresh',
#      'freshen'],
#     'hyponyms': ['breath',
#      'hot_air',
#      'liquid_air',
#      'mystique',
#      'note',
#      'vibration',
#      'vibe',
#      'breath',
#      'fresh_breeze',
#      'gentle_breeze',
#      'light_air',
#      'light_breeze',
#      'moderate_breeze',
#      'sea_breeze',
#      'strong_breeze',
#      'airspace',
#      'flourish',
#      'fanfare',
#      'tucket',
#      'glissando',
#      'leitmotiv',
#      'leitmotif',
#      'part',
#      'voice',
#      'roulade',
#      'signature',
#      'signature_tune',
#      'theme_song',
#      'theme',
#      'melodic_theme',
#      'musical_theme',
#      'idea',
#      'theme_song',
#      'flight',
#      'flying',
#      'get_on',
#      'be_on',
#      'interrogate',
#      'rerun',
#      'rebroadcast',
#      'satellite',
#      'sportscast',
#      'telecast',
#      'televise',
#      'air',
#      'send',
#      'broadcast',
#      'beam',
#      'transmit',
#      'bulletin',
#      'circulate',
#      'circularize',
#      'circularise',
#      'distribute',
#      'disseminate',
#      'propagate',
#      'broadcast',
#      'spread',
#      'diffuse',
#      'disperse',
#      'pass_around',
#      'hype',
#      'publish',
#      'bring_out',
#      'put_out',
#      'issue',
#      'release'],
#     'meronyms': ['airspace',
#      'air_space',
#      'ionosphere',
#      'phrase',
#      'musical_phrase'],
#     'synonyms': ['send',
#      'airwave',
#      'aura',
#      'melodic_phrase',
#      'breeze',
#      'atmosphere',
#      'beam',
#      'tune',
#      'air_travel',
#      'melodic_line',
#      'gentle_wind',
#      'aerate',
#      'air_out',
#      'broadcast',
#      'bare',
#      'air',
#      'melody',
#      'aviation',
#      'strain',
#      'publicize',
#      'transmit',
#      'ventilate',
#      'vent',
#      'zephyr',
#      'publicise',
#      'line']},
#    'and': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    'april': {'holonyms': [],
#     'hypernyms': ['Gregorian_calendar_month'],
#     'hyponyms': [],
#     'meronyms': ["April_Fools'",
#      "April_Fools'_day",
#      "All_Fools'_day",
#      'mid-April',
#      'Pan_American_Day',
#      'April_14',
#      "Patriot's_Day"],
#     'synonyms': ['April', 'Apr']},
#    'at': {'holonyms': [],
#     'hypernyms': ['chemical_element',
#      'element',
#      'halogen',
#      'Laotian_monetary_unit'],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': ['atomic_number_85', 'astatine', 'At', 'at']},
#    'base': {'holonyms': [],
#     'hypernyms': ['military_installation',
#      'support',
#      'baseball_equipment',
#      'part',
#      'piece',
#      'bottom',
#      'control',
#      'assumption',
#      'supposition',
#      'supposal',
#      'support',
#      'ester',
#      'compound',
#      'chemical_compound',
#      'flank',
#      'part',
#      'portion',
#      'component_part',
#      'component',
#      'constituent',
#      'number',
#      'location',
#      'form',
#      'word_form',
#      'signifier',
#      'descriptor',
#      'store',
#      'stock',
#      'fund',
#      'ingredient',
#      'bottom',
#      'underside',
#      'undersurface',
#      'electrode',
#      'situate',
#      'locate',
#      'drug',
#      'do_drugs'],
#     'hyponyms': ['air_base',
#      'air_station',
#      'army_base',
#      'firebase',
#      'navy_base',
#      'rocket_base',
#      'bed',
#      'raft_foundation',
#      'first_base',
#      'home_plate',
#      'home_base',
#      'home',
#      'plate',
#      'second_base',
#      'third_base',
#      'third',
#      'price_floor',
#      'wage_floor',
#      'meat_and_potatoes',
#      'brass_monkey',
#      'staddle',
#      'trivet',
#      'trivet',
#      'adenosine_diphosphate',
#      'ADP',
#      'adenosine_monophosphate',
#      'AMP',
#      'adenylic_acid',
#      'adenosine_triphosphate',
#      'ATP',
#      'base_pair',
#      'deoxyadenosine_monophosphate',
#      'A',
#      'deoxycytidine_monophosphate',
#      'C',
#      'deoxyguanosine_monophosphate',
#      'G',
#      'deoxythymidine_monophosphate',
#      'T',
#      'muton',
#      'uracil',
#      'U',
#      'imidazole',
#      'iminazole',
#      'glyoxaline',
#      'melamine',
#      'cyanuramide',
#      'purine',
#      'purine',
#      'pyridine',
#      'pyrimidine',
#      'build'],
#     'meronyms': ['communication_system',
#      'communication_equipment',
#      'fire_station',
#      'firehouse',
#      'gas_system',
#      'main',
#      'penal_institution',
#      'penal_facility',
#      'power_system',
#      'power_grid',
#      'grid',
#      'public_works',
#      'school_system',
#      'sewage_system',
#      'sewer_system',
#      'sewage_works',
#      'transportation_system',
#      'transportation',
#      'transit',
#      'water_system',
#      'water_supply',
#      'water'],
#     'synonyms': ['radix',
#      'immoral',
#      'theme',
#      'radical',
#      'meanspirited',
#      'Qaeda',
#      'root_word',
#      'ground',
#      'baseborn',
#      'foundation',
#      'base',
#      'understructure',
#      'substructure',
#      'bag',
#      'home',
#      'found',
#      'infrastructure',
#      'al-Qaeda',
#      'pedestal',
#      'Base',
#      'al-Qaida',
#      'humble',
#      'free-base',
#      'foot',
#      'cornerstone',
#      "al-Qa'ida",
#      'establish',
#      'basal',
#      'groundwork',
#      'root',
#      'basis',
#      'stand',
#      'mean',
#      'nucleotide',
#      'fundament',
#      'lowly',
#      'base_of_operations',
#      'alkali',
#      'floor',
#      'stem']},
#    'begin': {'holonyms': [],
#     'hypernyms': ['talk',
#      'speak',
#      'utter',
#      'mouth',
#      'verbalize',
#      'verbalise',
#      'be',
#      'be',
#      'act',
#      'move',
#      'achieve',
#      'accomplish',
#      'attain',
#      'reach'],
#     'hyponyms': ['attack',
#      'auspicate',
#      'break_in',
#      'come_on',
#      'embark',
#      'enter',
#      'fall',
#      'get_cracking',
#      'bestir_oneself',
#      'get_going',
#      'get_moving',
#      'get_weaving',
#      'get_started',
#      'get_rolling',
#      'get_to',
#      'jump_off',
#      'plunge',
#      'launch',
#      'recommence',
#      'strike_out',
#      'break_out',
#      'bud',
#      'dawn',
#      'erupt',
#      'break_out',
#      'originate',
#      'set_in',
#      'kick_in',
#      'inaugurate',
#      'usher_in',
#      'introduce',
#      'jumpstart',
#      'jump-start',
#      'recommence',
#      'set_off',
#      'start',
#      'start_up',
#      'embark_on',
#      'commence'],
#     'meronyms': [],
#     'synonyms': ['commence',
#      'Begin',
#      'get_down',
#      'begin',
#      'set_about',
#      'set_out',
#      'get',
#      'Menachem_Begin',
#      'start_out',
#      'start',
#      'lead_off']},
#    'edwards': {'holonyms': ['Windsor',
#      'House_of_Windsor',
#      'Saxe-Coburg-Gotha'],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': ['Duke_of_Windsor',
#      'Black_Prince',
#      'Edward_I',
#      'Edward_II',
#      'Edward_VII',
#      'Edward_IV',
#      'Jonathan_Edwards',
#      'Edwards',
#      'Albert_Edward',
#      'Prince_Edward',
#      'Edward_VI',
#      'Edward_Antony_Richard_Louis',
#      'Edward_V',
#      'Edward_VIII',
#      'Edward',
#      'Edward_III']},
#    'end': {'holonyms': ['football_team', 'eleven'],
#     'hypernyms': ['extremity',
#      'point',
#      'point_in_time',
#      'ending',
#      'conclusion',
#      'finish',
#      'content',
#      'cognitive_content',
#      'mental_object',
#      'part',
#      'section',
#      'division',
#      'state',
#      'surface',
#      'lineman',
#      'boundary',
#      'bound',
#      'bounds',
#      'topographic_point',
#      'place',
#      'spot',
#      'contribution',
#      'part',
#      'share',
#      'section',
#      'subdivision',
#      'piece_of_cloth',
#      'piece_of_material',
#      'lineman',
#      'change',
#      'alter',
#      'modify',
#      'be',
#      'destroy',
#      'destruct'],
#     'hyponyms': ['bitter_end',
#      'bitthead',
#      'end_point',
#      'endpoint',
#      'termination',
#      'terminus',
#      'finish',
#      'destination',
#      'goal',
#      'heel',
#      'heel',
#      'nerve_ending',
#      'nerve_end',
#      'point',
#      'pole',
#      'magnetic_pole',
#      'railhead',
#      'telomere',
#      'terminus',
#      'tip',
#      'yardarm',
#      'cease',
#      'death',
#      'dying',
#      'demise',
#      'death',
#      'last',
#      'fag_end',
#      'tail',
#      'tail_end',
#      'last_gasp',
#      'period',
#      'stopping_point',
#      'finale',
#      'finis',
#      'finish',
#      'last',
#      'conclusion',
#      'close',
#      'termination',
#      'expiration',
#      'expiry',
#      'terminus_ad_quem',
#      'terminal_point',
#      'limit',
#      'year-end',
#      'endgame',
#      'end_game',
#      'endgame',
#      'end_game',
#      'homestretch',
#      'passing',
#      'aim',
#      'object',
#      'objective',
#      'target',
#      'bourn',
#      'bourne',
#      'destination',
#      'terminus',
#      'end-all',
#      'intention',
#      'no-goal',
#      'purpose',
#      'intent',
#      'intention',
#      'aim',
#      'design',
#      'split_end',
#      'tight_end',
#      'anticlimax',
#      'bathos',
#      'epilogue',
#      'epilog',
#      'epilogue',
#      'epilog',
#      'finale',
#      'coda',
#      'peroration',
#      'fag_end',
#      'adjourn',
#      'recess',
#      'break_up',
#      'break',
#      'conclude',
#      'close',
#      'culminate',
#      'climax',
#      'cut_out',
#      'discontinue',
#      'go_out',
#      'lapse',
#      'pass_away',
#      'run_low',
#      'run_short',
#      'go',
#      'run_out',
#      'turn_out',
#      'come_out',
#      'vanish',
#      'disappear',
#      'go_away',
#      'vanish',
#      'disappear',
#      'abort',
#      'ax',
#      'axe',
#      'break',
#      'break_off',
#      'discontinue',
#      'stop',
#      'close',
#      'close',
#      'close_out',
#      'closure',
#      'cloture',
#      'complete',
#      'finish',
#      'conclude',
#      'culminate',
#      'decide',
#      'settle',
#      'resolve',
#      'adjudicate',
#      'dissolve',
#      'break_up',
#      'dissolve',
#      'break_up',
#      'finalize',
#      'finalise',
#      'settle',
#      'nail_down',
#      'finish',
#      'interrupt',
#      'break',
#      'lift',
#      'raise',
#      'phase_out',
#      'stamp_out',
#      'kill',
#      'stub_out',
#      'crush_out',
#      'extinguish',
#      'press_out',
#      'close'],
#     'meronyms': [],
#     'synonyms': ['final_stage',
#      'ending',
#      'cease',
#      'terminate',
#      'death',
#      'end',
#      'closing',
#      'remnant',
#      'finish',
#      'close',
#      'stop',
#      'remainder',
#      'goal',
#      'conclusion',
#      'oddment',
#      'last',
#      'destruction',
#      'terminal']},
#    'film': {'holonyms': [],
#     'hypernyms': ['product',
#      'production',
#      'show',
#      'medium',
#      'photographic_paper',
#      'photographic_material',
#      'object',
#      'physical_object',
#      'sheet',
#      'flat_solid',
#      'wrapping',
#      'wrap',
#      'wrapper',
#      'record',
#      'enter',
#      'put_down',
#      'make',
#      'create',
#      'record',
#      'enter',
#      'put_down'],
#     'hyponyms': ['cinema_verite',
#      'collage_film',
#      'coming_attraction',
#      'documentary',
#      'docudrama',
#      'documentary_film',
#      'infotainment',
#      'feature',
#      'feature_film',
#      'film_noir',
#      'final_cut',
#      'home_movie',
#      'musical',
#      'musical_comedy',
#      'musical_theater',
#      'rough_cut',
#      "shoot-'em-up",
#      'short_subject',
#      'silent_movie',
#      'silent_picture',
#      'silents',
#      'skin_flick',
#      'slow_motion',
#      'talking_picture',
#      'talkie',
#      'telefilm',
#      'three-D',
#      '3-D',
#      '3D',
#      'silver_screen',
#      'film_clip',
#      'footage',
#      'microfilm',
#      'motion-picture_film',
#      'movie_film',
#      'cine-film',
#      'negative',
#      'orthochromatic_film',
#      'panchromatic_film',
#      'positive',
#      'reel',
#      'roll',
#      'roll_film',
#      'sequence',
#      'episode',
#      'X-ray_film',
#      'scum',
#      'slick',
#      'soap_film',
#      'Polaroid',
#      'shrink-wrap',
#      'reshoot',
#      'cinematize',
#      'cinematise',
#      'microfilm'],
#     'meronyms': ['credit',
#      'credits',
#      'scene',
#      'shot',
#      'sequence',
#      'episode',
#      'subtitle',
#      'caption'],
#     'synonyms': ['moving-picture_show',
#      'film',
#      'take',
#      'motion-picture_show',
#      'pic',
#      'motion_picture',
#      'cinema',
#      'shoot',
#      'plastic_film',
#      'picture',
#      'flick',
#      'movie',
#      'moving_picture',
#      'celluloid',
#      'picture_show',
#      'photographic_film']},
#    'force': {'holonyms': ['military_service', 'armed_service', 'service'],
#     'hypernyms': ['influence',
#      'physical_phenomenon',
#      'intensity',
#      'intensiveness',
#      'organization',
#      'organisation',
#      'unit',
#      'social_unit',
#      'aggression',
#      'hostility',
#      'causal_agent',
#      'cause',
#      'causal_agency',
#      'social_group',
#      'validity',
#      'validness',
#      'putout',
#      'compel',
#      'oblige',
#      'obligate',
#      'cause',
#      'do',
#      'make',
#      'move',
#      'displace',
#      'compel',
#      'oblige',
#      'obligate',
#      'move',
#      'displace',
#      'thrust',
#      'move',
#      'displace',
#      'act',
#      'move',
#      'penetrate',
#      'perforate'],
#     'hyponyms': ['duress',
#      'heartbeat',
#      'lifeblood',
#      'pressure',
#      'wheel',
#      'aerodynamic_force',
#      'affinity',
#      'chemical_attraction',
#      'attraction',
#      'attractive_force',
#      'centrifugal_force',
#      'centripetal_force',
#      'cohesion',
#      'Coriolis_force',
#      'drift',
#      'impetus',
#      'impulsion',
#      'life_force',
#      'vital_force',
#      'vitality',
#      'elan_vital',
#      'Lorentz_force',
#      'magnetomotive_force',
#      'moment',
#      'propulsion',
#      'pull',
#      'push',
#      'thrust',
#      'reaction',
#      'repulsion',
#      'repulsive_force',
#      'stress',
#      'torsion',
#      'torque',
#      'brunt',
#      'energy',
#      'vigor',
#      'vigour',
#      'zip',
#      'momentum',
#      'impulse',
#      'guerrilla_force',
#      'guerilla_force',
#      'line_personnel',
#      'management_personnel',
#      'military',
#      'armed_forces',
#      'armed_services',
#      'military_machine',
#      'war_machine',
#      'military_personnel',
#      'soldiery',
#      'troops',
#      'military_police',
#      'MP',
#      'military_service',
#      'armed_service',
#      'service',
#      'paramilitary',
#      'paramilitary_force',
#      'paramilitary_unit',
#      'paramilitary_organization',
#      'paramilitary_organisation',
#      'patrol',
#      'police',
#      'police_force',
#      'constabulary',
#      'law',
#      'rank_and_file',
#      'rank',
#      'security_force',
#      'private_security_force',
#      'staff',
#      'work_force',
#      'workforce',
#      'manpower',
#      'hands',
#      'men',
#      'air_unit',
#      'armor',
#      'armour',
#      'army_unit',
#      'command',
#      'commando',
#      'contingent',
#      'detail',
#      'echelon',
#      'enemy',
#      'guard',
#      'Haganah',
#      'headquarters',
#      'Israeli_Defense_Force',
#      'IDF',
#      'legion',
#      'militia',
#      'reserves',
#      'mujahidin',
#      'mujahedin',
#      'mujahedeen',
#      'mujahadeen',
#      'mujahadin',
#      'mujahideen',
#      'mujahadein',
#      'naval_unit',
#      'phalanx',
#      'Republican_Guard',
#      'spearhead',
#      'task_force',
#      'trip_wire',
#      'domestic_violence',
#      'riot',
#      'public_violence',
#      'road_rage',
#      'influence',
#      'juggernaut',
#      'steamroller',
#      'Moloch',
#      'bludgeon',
#      'bring_oneself',
#      'dragoon',
#      'sandbag',
#      'railroad',
#      'drive',
#      'squeeze_for',
#      'steamroller',
#      'steamroll',
#      'terrorize',
#      'terrorise',
#      'turn_up_the_heat',
#      'turn_up_the_pressure',
#      'drive',
#      'jam',
#      'jerk',
#      'flick',
#      'jostle',
#      'shove',
#      'muscle_into',
#      'nose',
#      'nudge',
#      'poke_at',
#      'prod',
#      'press',
#      'push',
#      'push_aside',
#      'push_away',
#      'push_out',
#      'obtrude',
#      'thrust_out',
#      'push_up',
#      'repel',
#      'drive',
#      'repulse',
#      'force_back',
#      'push_back',
#      'beat_back',
#      'shove',
#      'thrust',
#      'thrust',
#      'stuff',
#      'shove',
#      'squeeze',
#      'topple',
#      'tumble',
#      'tip',
#      'stick',
#      'sting',
#      'compress',
#      'compact',
#      'pack_together',
#      'impact',
#      'toe',
#      'toenail',
#      'abduct',
#      'adduct',
#      'attract',
#      'pull',
#      'pull_in',
#      'draw',
#      'draw_in',
#      'drag',
#      'haul',
#      'hale',
#      'cart',
#      'drag',
#      'pluck',
#      'tweak',
#      'pull_off',
#      'pick_off',
#      'pluck',
#      'plunk',
#      'pick',
#      'pull_back',
#      'stretch',
#      'tug',
#      'twitch',
#      'winch',
#      'yank',
#      'jerk',
#      'pull'],
#     'meronyms': [],
#     'synonyms': ['force-out',
#      'thrust',
#      'strength',
#      'force_out',
#      'storm',
#      'impel',
#      'power',
#      'hale',
#      'force_play',
#      'military_force',
#      'effect',
#      'violence',
#      'coerce',
#      'force',
#      'pressure',
#      'ram',
#      'squeeze',
#      'pull',
#      'wedge',
#      'forcefulness',
#      'military_group',
#      'push',
#      'military_unit',
#      'draw',
#      'personnel',
#      'drive']},
#    'in': {'holonyms': [],
#     'hypernyms': ['linear_unit',
#      'linear_measure',
#      'metallic_element',
#      'metal'],
#     'hyponyms': [],
#     'meronyms': ['em',
#      'pica_em',
#      'pica',
#      'ligne',
#      'mesh',
#      'mil',
#      'Bloomington',
#      'Evansville',
#      'Fort_Wayne',
#      'Gary',
#      'Indianapolis',
#      'capital_of_Indiana',
#      'Lafayette',
#      'Muncie',
#      'South_Bend',
#      'Wabash',
#      'Wabash_River'],
#     'synonyms': ['Indiana',
#      'inwards',
#      'In',
#      'inch',
#      'in',
#      'IN',
#      'indium',
#      'inward',
#      'atomic_number_49',
#      'Hoosier_State']},
#    'may': {'holonyms': ['Crataegus', 'genus_Crataegus'],
#     'hypernyms': ['Gregorian_calendar_month', 'hawthorn', 'haw'],
#     'hyponyms': [],
#     'meronyms': ['Armed_Forces_Day',
#      'Commonwealth_Day',
#      'Empire_day',
#      'May_24',
#      'May_Day',
#      'First_of_May',
#      'May_1',
#      'Memorial_Day',
#      'Decoration_Day',
#      'mid-May',
#      "Mother's_Day"],
#     'synonyms': ['Crataegus_laevigata',
#      'Crataegus_oxycantha',
#      'may',
#      'English_hawthorn',
#      'May',
#      'whitethorn']},
#    'mid': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': ['mid']},
#    'on': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': ['along', 'on']}}},
#  'It was selected by the American Film Institute as one of the ten best films of the year.': {'POS_tag': {It: 'PRP',
#    was: 'VBD',
#    selected: 'VBN',
#    by: 'IN',
#    the: 'DT',
#    American: 'NNP',
#    Film: 'NNP',
#    Institute: 'NNP',
#    as: 'IN',
#    one: 'CD',
#    of: 'IN',
#    the: 'DT',
#    ten: 'CD',
#    best: 'JJS',
#    films: 'NNS',
#    of: 'IN',
#    the: 'DT',
#    year: 'NN',
#    .: '.'},
#   'dependency_tree': [['It', 'nsubjpass', 'selected', 'VERB', []],
#    ['was', 'auxpass', 'selected', 'VERB', []],
#    ['selected', 'ROOT', 'selected', 'VERB', [It, was, by, as, .]],
#    ['by', 'agent', 'selected', 'VERB', [Institute]],
#    ['the', 'det', 'Institute', 'PROPN', []],
#    ['American', 'compound', 'Institute', 'PROPN', []],
#    ['Film', 'compound', 'Institute', 'PROPN', []],
#    ['Institute', 'pobj', 'by', 'ADP', [the, American, Film]],
#    ['as', 'prep', 'selected', 'VERB', [one]],
#    ['one', 'pobj', 'as', 'ADP', [of]],
#    ['of', 'prep', 'one', 'NUM', [films]],
#    ['the', 'det', 'films', 'NOUN', []],
#    ['ten', 'nummod', 'films', 'NOUN', []],
#    ['best', 'amod', 'films', 'NOUN', []],
#    ['films', 'pobj', 'of', 'ADP', [the, ten, best, of]],
#    ['of', 'prep', 'films', 'NOUN', [year]],
#    ['the', 'det', 'year', 'NOUN', []],
#    ['year', 'pobj', 'of', 'ADP', [the]],
#    ['.', 'punct', 'selected', 'VERB', []]],
#   'lemmas': ['-PRON-',
#    'be',
#    'select',
#    'by',
#    'the',
#    'american',
#    'film',
#    'institute',
#    'as',
#    'one',
#    'of',
#    'the',
#    'ten',
#    'good',
#    'film',
#    'of',
#    'the',
#    'year',
#    '.'],
#   'word_net_info': {'-PRON-': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    '.': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    'american': {'holonyms': ['United_States',
#      'United_States_of_America',
#      'America',
#      'the_States',
#      'US',
#      'U.S.',
#      'USA',
#      'U.S.A.',
#      'Central_America',
#      'North_America',
#      'South_America'],
#     'hypernyms': ['inhabitant',
#      'habitant',
#      'dweller',
#      'denizen',
#      'indweller',
#      'English',
#      'English_language',
#      'inhabitant',
#      'habitant',
#      'dweller',
#      'denizen',
#      'indweller'],
#     'hyponyms': ['African-American',
#      'African_American',
#      'Afro-American',
#      'Black_American',
#      'Alabaman',
#      'Alabamian',
#      'Alaskan',
#      'Anglo-American',
#      'Appalachian',
#      'Arizonan',
#      'Arizonian',
#      'Arkansan',
#      'Arkansawyer',
#      'Asian_American',
#      'Bay_Stater',
#      'Bostonian',
#      'Californian',
#      'Carolinian',
#      'Coloradan',
#      'Connecticuter',
#      'Creole',
#      'Delawarean',
#      'Delawarian',
#      'Floridian',
#      'Franco-American',
#      'Georgian',
#      'German_American',
#      'Hawaiian',
#      'Idahoan',
#      'Illinoisan',
#      'Indianan',
#      'Hoosier',
#      'Iowan',
#      'Kansan',
#      'Kentuckian',
#      'Bluegrass_Stater',
#      'Louisianan',
#      'Louisianian',
#      'Mainer',
#      'Down_Easter',
#      'Marylander',
#      'Michigander',
#      'Wolverine',
#      'Minnesotan',
#      'Gopher',
#      'Mississippian',
#      'Missourian',
#      'Montanan',
#      'Nebraskan',
#      'Cornhusker',
#      'Nevadan',
#      'New_Englander',
#      'Yankee',
#      'New_Hampshirite',
#      'Granite_Stater',
#      'New_Jerseyan',
#      'New_Jerseyite',
#      'Garden_Stater',
#      'New_Mexican',
#      'New_Yorker',
#      'Nisei',
#      'North_Carolinian',
#      'Tarheel',
#      'North_Dakotan',
#      'Ohioan',
#      'Buckeye',
#      'Oklahoman',
#      'Sooner',
#      'Oregonian',
#      'Beaver',
#      'Pennsylvanian',
#      'Keystone_Stater',
#      'Puerto_Rican',
#      'Rhode_Islander',
#      'South_Carolinian',
#      'South_Dakotan',
#      'Southerner',
#      'Spanish_American',
#      'Hispanic_American',
#      'Hispanic',
#      'Tennessean',
#      'Volunteer',
#      'Texan',
#      'Tory',
#      'Utahan',
#      'Vermonter',
#      'Virginian',
#      'Washingtonian',
#      'Washingtonian',
#      'West_Virginian',
#      'Wisconsinite',
#      'Badger',
#      'Wyomingite',
#      'Yankee',
#      'Yank',
#      'Northerner',
#      'Yankee',
#      'Yank',
#      'Yankee-Doodle',
#      'African_American_Vernacular_English',
#      'AAVE',
#      'African_American_English',
#      'Black_English',
#      'Black_English_Vernacular',
#      'Black_Vernacular',
#      'Black_Vernacular_English',
#      'Ebonics',
#      'Creole',
#      'Latin_American',
#      'Latino',
#      'Mesoamerican',
#      'North_American',
#      'South_American',
#      'West_Indian'],
#     'meronyms': [],
#     'synonyms': ['American_English', 'American_language', 'American']},
#    'as': {'holonyms': ['Roman_alphabet', 'Latin_alphabet'],
#     'hypernyms': ['chemical_element',
#      'element',
#      'metric_linear_unit',
#      'fat-soluble_vitamin',
#      'nucleotide',
#      'base',
#      'purine',
#      'current_unit',
#      'letter',
#      'letter_of_the_alphabet',
#      'alphabetic_character',
#      'blood_group',
#      'blood_type'],
#     'hyponyms': ['vitamin_A1', 'retinol', 'vitamin_A2', 'dehydroretinol'],
#     'meronyms': ['Pago_Pago',
#      'Pango_Pango',
#      'picometer',
#      'picometre',
#      'micromicron',
#      'milliampere',
#      'mA'],
#     'synonyms': ['adenine',
#      'equally',
#      'A',
#      'angstrom',
#      'atomic_number_33',
#      'vitamin_A',
#      'ampere',
#      'angstrom_unit',
#      'as',
#      'group_A',
#      'American_Samoa',
#      'amp',
#      'As',
#      'Eastern_Samoa',
#      'axerophthol',
#      'arsenic',
#      'type_A',
#      'AS',
#      'deoxyadenosine_monophosphate',
#      'antiophthalmic_factor',
#      'every_bit',
#      'a']},
#    'be': {'holonyms': [],
#     'hypernyms': ['metallic_element',
#      'metal',
#      'typify',
#      'symbolize',
#      'symbolise',
#      'stand_for',
#      'represent',
#      'take',
#      'occupy',
#      'use_up',
#      'stay',
#      'remain',
#      'rest',
#      'be'],
#     'hyponyms': ['abound',
#      'accept',
#      'take',
#      'account',
#      'account_for',
#      'act',
#      'answer',
#      'appear',
#      'seem',
#      'bake',
#      'broil',
#      'balance',
#      'be_well',
#      'beat',
#      'begin',
#      'begin',
#      'start',
#      'belong',
#      'belong',
#      'belong',
#      'belong',
#      'breathe',
#      'buy',
#      'clean',
#      'cohere',
#      'come_in_for',
#      'come_in_handy',
#      'compact',
#      'pack',
#      'compare',
#      'confuse',
#      'throw',
#      'fox',
#      'befuddle',
#      'fuddle',
#      'bedevil',
#      'confound',
#      'discombobulate',
#      'connect',
#      'consist',
#      'consist',
#      'comprise',
#      'contain',
#      'contain',
#      'take',
#      'hold',
#      'continue',
#      'cost',
#      'be',
#      'count',
#      'matter',
#      'weigh',
#      'count',
#      'cover',
#      'cut',
#      'cut_across',
#      'deck',
#      'adorn',
#      'decorate',
#      'grace',
#      'embellish',
#      'beautify',
#      'depend',
#      'deserve',
#      'merit',
#      'disagree',
#      'disaccord',
#      'discord',
#      'distribute',
#      'diverge',
#      'draw',
#      'end',
#      'terminate',
#      'fall',
#      'come',
#      'fall',
#      'feel',
#      'figure',
#      'enter',
#      'fit',
#      'gape',
#      'yawn',
#      'yaw',
#      'go',
#      'gravitate',
#      'hail',
#      'come',
#      'hang',
#      'head',
#      'head_up',
#      'hold',
#      'hoodoo',
#      'hum',
#      'buzz',
#      'seethe',
#      'impend',
#      'incarnate',
#      'body_forth',
#      'embody',
#      'substantiate',
#      'iridesce',
#      'jumble',
#      'mingle',
#      'kill',
#      'lend',
#      'let_go',
#      'lie',
#      'litter',
#      'loiter',
#      'lounge',
#      'footle',
#      'lollygag',
#      'loaf',
#      'lallygag',
#      'hang_around',
#      'mess_about',
#      'tarry',
#      'linger',
#      'lurk',
#      'mill_about',
#      'mill_around',
#      'look',
#      'appear',
#      'seem',
#      'look',
#      'lubricate',
#      'make',
#      'make_sense',
#      'add_up',
#      'measure',
#      'mope',
#      'moon_around',
#      'moon_about',
#      'object',
#      'osculate',
#      'owe',
#      'pay',
#      'point',
#      'press',
#      'promise',
#      'prove',
#      'turn_out',
#      'turn_up',
#      'put_out',
#      'rage',
#      'range',
#      'run',
#      'rank',
#      'rate',
#      'recognize',
#      'relate',
#      'interrelate',
#      'remain',
#      'represent',
#      'rest',
#      'retard',
#      'run',
#      'go',
#      'run_into',
#      'encounter',
#      'rut',
#      'seem',
#      'seethe',
#      'boil',
#      'sell',
#      'sell',
#      'sell',
#      'shine',
#      'shine',
#      'sparkle',
#      'scintillate',
#      'coruscate',
#      'specify',
#      'define',
#      'delineate',
#      'delimit',
#      'delimitate',
#      'squat',
#      'stagnate',
#      'stagnate',
#      'stand',
#      'stand',
#      'stand_by',
#      'stick_by',
#      'stick',
#      'adhere',
#      'stay',
#      'remain',
#      'rest',
#      'stay',
#      'stay_on',
#      'continue',
#      'remain',
#      'stick',
#      'stink',
#      'subtend',
#      'delimit',
#      'suck',
#      'suffer',
#      'hurt',
#      'suffer',
#      'suit',
#      'swim',
#      'swim',
#      'drown',
#      'swing',
#      'tend',
#      'be_given',
#      'lean',
#      'incline',
#      'run',
#      'test',
#      'total',
#      'number',
#      'add_up',
#      'come',
#      'amount',
#      'translate',
#      'transplant',
#      'trim',
#      'underlie',
#      'want',
#      'need',
#      'require',
#      'wash',
#      'wind',
#      'twist',
#      'curve',
#      'work',
#      'attend',
#      'go_to',
#      'belong',
#      'go',
#      'center_on',
#      'come',
#      'cover',
#      'continue',
#      'extend',
#      'extend',
#      'poke_out',
#      'reach_out',
#      'face',
#      'follow',
#      'go',
#      'lead',
#      'inhabit',
#      'lie',
#      'lie',
#      'rest',
#      'occupy',
#      'fill',
#      'populate',
#      'dwell',
#      'live',
#      'inhabit',
#      'reach',
#      'extend_to',
#      'touch',
#      'run',
#      'go',
#      'pass',
#      'lead',
#      'extend',
#      'sit',
#      'sit_around',
#      'sit',
#      'stand_back',
#      "keep_one's_eyes_off",
#      "keep_one's_distance",
#      "keep_one's_hands_off",
#      'stay_away',
#      'straddle',
#      'stretch',
#      'stretch_along',
#      'coexist',
#      'come',
#      'distribute',
#      'dwell',
#      'consist',
#      'lie',
#      'lie_in',
#      'dwell',
#      'inhabit',
#      'endanger',
#      'jeopardize',
#      'jeopardise',
#      'menace',
#      'threaten',
#      'imperil',
#      'peril',
#      'flow',
#      'indwell',
#      'kick_around',
#      'knock_about',
#      'kick_about',
#      'preexist',
#      'prevail',
#      'hold',
#      'obtain',
#      'equate',
#      'correspond',
#      'match',
#      'fit',
#      'correspond',
#      'check',
#      'jibe',
#      'gibe',
#      'tally',
#      'agree',
#      'represent',
#      'stand_for',
#      'correspond',
#      'translate',
#      'compose',
#      'fall_into',
#      'fall_under',
#      'form',
#      'constitute',
#      'make',
#      'make',
#      'present',
#      'pose',
#      'range',
#      'straddle',
#      'supplement',
#      'cox',
#      'vet',
#      'body',
#      'personify',
#      'exemplify',
#      'represent',
#      'set_back',
#      'knock_back',
#      'put_back'],
#     'meronyms': [],
#     'synonyms': ['personify',
#      'equal',
#      'constitute',
#      'follow',
#      'cost',
#      'represent',
#      'live',
#      'Be',
#      'exist',
#      'embody',
#      'beryllium',
#      'be',
#      'comprise',
#      'atomic_number_4',
#      'glucinium',
#      'make_up']},
#    'by': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': ['by', 'aside', 'past', 'away']},
#    'film': {'holonyms': [],
#     'hypernyms': ['product',
#      'production',
#      'show',
#      'medium',
#      'photographic_paper',
#      'photographic_material',
#      'object',
#      'physical_object',
#      'sheet',
#      'flat_solid',
#      'wrapping',
#      'wrap',
#      'wrapper',
#      'record',
#      'enter',
#      'put_down',
#      'make',
#      'create',
#      'record',
#      'enter',
#      'put_down'],
#     'hyponyms': ['cinema_verite',
#      'collage_film',
#      'coming_attraction',
#      'documentary',
#      'docudrama',
#      'documentary_film',
#      'infotainment',
#      'feature',
#      'feature_film',
#      'film_noir',
#      'final_cut',
#      'home_movie',
#      'musical',
#      'musical_comedy',
#      'musical_theater',
#      'rough_cut',
#      "shoot-'em-up",
#      'short_subject',
#      'silent_movie',
#      'silent_picture',
#      'silents',
#      'skin_flick',
#      'slow_motion',
#      'talking_picture',
#      'talkie',
#      'telefilm',
#      'three-D',
#      '3-D',
#      '3D',
#      'silver_screen',
#      'film_clip',
#      'footage',
#      'microfilm',
#      'motion-picture_film',
#      'movie_film',
#      'cine-film',
#      'negative',
#      'orthochromatic_film',
#      'panchromatic_film',
#      'positive',
#      'reel',
#      'roll',
#      'roll_film',
#      'sequence',
#      'episode',
#      'X-ray_film',
#      'scum',
#      'slick',
#      'soap_film',
#      'Polaroid',
#      'shrink-wrap',
#      'reshoot',
#      'cinematize',
#      'cinematise',
#      'microfilm'],
#     'meronyms': ['credit',
#      'credits',
#      'scene',
#      'shot',
#      'sequence',
#      'episode',
#      'subtitle',
#      'caption'],
#     'synonyms': ['moving-picture_show',
#      'film',
#      'take',
#      'motion-picture_show',
#      'pic',
#      'motion_picture',
#      'cinema',
#      'shoot',
#      'plastic_film',
#      'picture',
#      'flick',
#      'movie',
#      'moving_picture',
#      'celluloid',
#      'picture_show',
#      'photographic_film']},
#    'good': {'holonyms': [],
#     'hypernyms': ['advantage',
#      'vantage',
#      'morality',
#      'quality',
#      'artifact',
#      'artefact'],
#     'hyponyms': ['common_good',
#      'commonweal',
#      'beneficence',
#      'benignity',
#      'benignancy',
#      'graciousness',
#      'kindness',
#      'saintliness',
#      'summum_bonum',
#      'virtue',
#      'virtuousness',
#      'moral_excellence',
#      'virtue',
#      'benefit',
#      'welfare',
#      'better',
#      'better',
#      'desirability',
#      'desirableness',
#      'optimum',
#      'wisdom',
#      'wiseness',
#      'soundness',
#      'worthiness',
#      'basic',
#      'staple',
#      'consumer_goods',
#      'drygoods',
#      'soft_goods',
#      'entrant',
#      'export',
#      'exportation',
#      'fancy_goods',
#      'fungible',
#      'future',
#      'import',
#      'importation',
#      'merchandise',
#      'ware',
#      'product',
#      'middling',
#      'salvage',
#      'shopping',
#      'sporting_goods',
#      'worldly_possession',
#      'worldly_good'],
#     'meronyms': [],
#     'synonyms': ['well',
#      'unspoiled',
#      'full',
#      'near',
#      'estimable',
#      'in_effect',
#      'skillful',
#      'serious',
#      'sound',
#      'trade_good',
#      'goodness',
#      'practiced',
#      'ripe',
#      'thoroughly',
#      'just',
#      'right',
#      'salutary',
#      'adept',
#      'dear',
#      'proficient',
#      'soundly',
#      'honest',
#      'beneficial',
#      'unspoilt',
#      'skilful',
#      'secure',
#      'safe',
#      'dependable',
#      'effective',
#      'good',
#      'upright',
#      'in_force',
#      'honorable',
#      'respectable',
#      'expert',
#      'undecomposed',
#      'commodity']},
#    'institute': {'holonyms': [],
#     'hypernyms': ['association', 'initiate', 'pioneer', 'make', 'create'],
#     'hyponyms': ['appoint', 'name', 'nominate', 'constitute', 'fix'],
#     'meronyms': [],
#     'synonyms': ['constitute',
#      'establish',
#      'bring',
#      'institute',
#      'found',
#      'plant']},
#    'of': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    'one': {'holonyms': [],
#     'hypernyms': ['digit', 'figure', 'unit'],
#     'hyponyms': ['monad', 'monas', 'singleton'],
#     'meronyms': [],
#     'synonyms': ['single',
#      'peerless',
#      'unrivalled',
#      'ane',
#      'unrivaled',
#      'i',
#      'nonpareil',
#      'ace',
#      'unitary',
#      'I',
#      'matchless',
#      'unmatched',
#      'unmatchable',
#      'one_and_only',
#      'unity',
#      'one',
#      '1']},
#    'select': {'holonyms': [],
#     'hypernyms': ['decide', "make_up_one's_mind", 'determine'],
#     'hyponyms': ['adopt',
#      'follow',
#      'espouse',
#      'anoint',
#      'assign',
#      'specify',
#      'set_apart',
#      'cream_off',
#      'skim_off',
#      'cull_out',
#      'winnow',
#      'dial',
#      'draw',
#      'elect',
#      'elect',
#      'empanel',
#      'impanel',
#      'panel',
#      'excerpt',
#      'extract',
#      'take_out',
#      'field',
#      'nominate',
#      'propose',
#      'pick',
#      'plump',
#      'go',
#      'screen',
#      'screen_out',
#      'sieve',
#      'sort',
#      'sieve',
#      'sift',
#      'sieve_out',
#      'pick_over',
#      'single_out',
#      'specify',
#      'set',
#      'determine',
#      'define',
#      'fix',
#      'limit',
#      'think_of',
#      'vote',
#      'vote_in'],
#     'meronyms': [],
#     'synonyms': ['prize',
#      'blue-ribbon',
#      'take',
#      'choose',
#      'quality',
#      'prime',
#      'select',
#      'choice',
#      'pick_out']},
#    'ten': {'holonyms': [],
#     'hypernyms': ['large_integer', 'spot'],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': ['tenner', 'X', 'ten-spot', '10', 'x', 'ten', 'decade']},
#    'the': {'holonyms': [],
#     'hypernyms': [],
#     'hyponyms': [],
#     'meronyms': [],
#     'synonyms': []},
#    'year': {'holonyms': [],
#     'hypernyms': ['time_period',
#      'period_of_time',
#      'period',
#      'time_period',
#      'period_of_time',
#      'period',
#      'time_period',
#      'period_of_time',
#      'period',
#      'gathering',
#      'assemblage'],
#     'hyponyms': ['annum',
#      'calendar_year',
#      'civil_year',
#      'church_year',
#      'Christian_year',
#      'common_year',
#      '365_days',
#      'fiscal_year',
#      'financial_year',
#      'Holy_Year',
#      'leap_year',
#      'intercalary_year',
#      '366_days',
#      'bissextile_year',
#      'New_Year',
#      'off_year',
#      'off_year',
#      'Y2K',
#      'year_of_grace',
#      'school_year',
#      'academic_year',
#      'anomalistic_year',
#      'lunar_year',
#      'sidereal_year',
#      'solar_year',
#      'tropical_year',
#      'astronomical_year',
#      'equinoctial_year',
#      'freshman_class',
#      'graduating_class',
#      'junior_class',
#      'senior_class',
#      'sophomore_class'],
#     'meronyms': ['month', 'season', 'time_of_year'],
#     'synonyms': ['twelvemonth', 'class', 'year', 'yr']}}}}
